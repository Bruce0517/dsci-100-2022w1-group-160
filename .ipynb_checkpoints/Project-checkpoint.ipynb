# %% [markdown]
# # Determining the most characteristic predictor of a Pulsar Star

# %% [markdown]
# ## Introduction

# %% [markdown]
# The advent of the digital age is synonymous an increased interest of individuals, industries, and academia alike in outer space. This knowledge has helped us to better understand our place in the universe and has also had practical applications here on Earth. For example, research conducted in space has led to the development of new technologies, such as satellite-based communication and navigation systems, as well as advances in medical treatments and materials science. In addition, space exploration has also inspired wonder and curiosity in people, which can drive us to continue pushing the boundaries of what is possible and to strive for new achievements.
#
# Pulsars are high-energy neutron stars that emit beams of electromagnetic radiation through their magnetic poles in regular pulses. As probes of space-time, the interstellar medium, and states of matter, pulsars are of great scientific interest (Lorimer and Kramer). Unfortunately, in reality, radio frequency interference (RFI) and noise account for almost all pulsar candidates, making it challenging to locate real signals of pulsars. To speed up analysis, pulsar candidates are now being automatically labelled using machine learning methods (Eatough).
#
# This report will look to contribute to the collective effort of using predictive models to answer the question: **Which of a pulsar candidate's characteristics best indicates whether it is a pulsar star or not?**

# %% [markdown]
# The dataset being analysed comes from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/HTRU2). A selection of pulsar candidates are described in the HTRU2 dataset. There are eight numerical variables, that each describe a characteristic of a pulsar candidate. These variables are the mean, standard deviation, excess kurtosis, and skewness of the observed pulsar candiate, as described by the integrated pulse profile and the DM-SNR curve of the pulsar candidates. A pulsar's integrated pulse profile is a graph or profile that shows the radiation emission associated with each pulse (Lyon). And the DM-SNR curve is a graph that entails the dispersion measure of the signal-to-noise ratio of a pulsar candidate (Lyon). A pulsar's emission is one of its distinguishing features, therefore monitoring it and collecting the data in the form of integrated pulse profiles and DM-SNR curves enables us to gather crucial information. It is important to understand these two key elements used to derive the data in the HTRU2 dataset.

# %% [markdown]
# ## Methods and Results

# %% [markdown]
# The relevant libraries can be loaded and the dataset can be read from the web to R and tidied, as follows:

# %%
library(tidyverse)
library(tidymodels)
library(parallel)
library(RColorBrewer)
htru_data <- read_csv(
    "https://github.com/Bruce0517/dsci-100-2022w1-group-160/raw/main/HTRU_2.csv", 
    col_names = c("p.mean", "p.sd", "p.kurt", "p.skew",
                  "c.mean", "c.sd", "c.kurt", "c.skew", "class")) |>
    mutate(class = ifelse(class == 1, "Pulsar", "Non-pulsar")) |>
    mutate(class = as_factor(class))
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.6     ✔ purrr   0.3.4
# ✔ tibble  3.1.7     ✔ dplyr   1.0.9
# ✔ tidyr   1.2.0     ✔ stringr 1.4.0
# ✔ readr   2.1.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# ── Attaching packages ────────────────────────────────────── tidymodels 1.0.0 ──
#
# ✔ broom        1.0.0     ✔ rsample      1.0.0
# ✔ dials        1.0.0     ✔ tune         1.0.0
# ✔ infer        1.0.2     ✔ workflows    1.0.0
# ✔ modeldata    1.0.0     ✔ workflowsets 1.0.0
# ✔ parsnip      1.0.0     ✔ yardstick    1.0.0
# ✔ recipes      1.0.1
#
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ scales::discard() masks purrr::discard()
# ✖ dplyr::filter()   masks stats::filter()
# ✖ recipes::fixed()  masks stringr::fixed()
# ...

# %% [markdown]
# The data did not have column names, so column names needed to be added. The class name was then made more human-readable and made a factor, to facilitate data analysis.

# %% [markdown]
# As described above, the data is a description of data gathered from pulsar candidates. Here is a sample of some pulsars and non-pulsars:

# %%
set.seed(69420)
bind_rows(sample_n(filter(htru_data, class == "Non-pulsar"), 3),
          sample_n(filter(htru_data, class == "Pulsar"), 3))
# Out:
#   p.mean    p.sd     p.kurt    p.skew     c.mean    c.sd     c.kurt
# 1 100.14844 41.15787 0.6187296  1.5244102  1.732441 16.48696 12.498927
# 2 110.16406 40.31318 0.5820537  0.7071917  3.343645 18.43795  8.038802
# 3 131.17969 48.99863 0.0702603 -0.1755943 14.413880 43.49945  3.073368
# 4 100.39844 39.28369 0.3695178  0.9012783  2.649666 21.38761  8.520892
# 5  58.78906 33.07724 2.8263069 15.0398616 17.257525 54.34239  3.192879
# 6  65.78125 45.98946 2.5732238  7.6958315 18.548495 52.68814  3.005062
#   c.skew     class
# 1 168.368092 Non-pulsar
# 2  81.182894 Non-pulsar
# 3   8.639341 Non-pulsar
# 4  74.554360 Pulsar
# 5   9.012004 Pulsar
# 6   8.190395 Pulsar

# %% [markdown]
# The data must be separated into training and testing sets, as it is known from the research question predictive algorithm must be applied to the data. This is done as follows:

# %%
set.seed(69420)

# Proportion is low to lower memory usage and computing time later
htru_split <- initial_split(htru_data, prop = .5, strata = class)  
htru_train <- training(htru_split)   
htru_test <- testing(htru_split)

# %% [markdown]
# Here is the number of pulsars and non-pulsars in the training set and the average for each variable:

# %%
htru_train |>
    group_by(class) |>
    summarize(n = n(), p.mean = mean(p.mean), p.sd = mean(p.sd), p.kurt = mean(p.kurt), p.skew = mean(p.skew),
                       c.mean = mean(c.mean), c.sd = mean(c.sd), c.kurt = mean(c.kurt), c.skew = mean(c.skew))
# Out:
#   class      n    p.mean    p.sd     p.kurt    p.skew     c.mean    c.sd
# 1 Non-pulsar 8135 116.55383 47.24958 0.2095486  0.3907247  8.708427 23.30529
# 2 Pulsar      814  57.99119 38.74257 3.0810694 15.2339659 49.386423 56.25237
#   c.kurt   c.skew
# 1 8.840782 113.11916
# 2 2.721068  16.65216

# %% [markdown]
# It should be noted that there are no missing values that need to be. ahndled in the dataset, hence the `na.rm = TRUE` argument was not required when calculating the `mean` values. The following is a histogram for each variable from a sample of 500 of each class, created using the mean values, to compare the distributions of the predictor variables:

# %%
options(repr.plot.width=20, repr.plot.height=16)
set.seed(69420)

factor_levels <- c("p.mean", "c.mean", "p.sd", "c.sd", "p.kurt", "c.kurt", "p.skew", "c.skew")
untidy <- function(data) {  # To plot the data we must first untidy it
    data |>
    pivot_longer(-class, names_to = "preds", values_to = "vals") |> 
    mutate(preds = factor(preds, levels = factor_levels))
}
pulsar_sample <- untidy(filter(htru_train, class == "Non-pulsar") |> sample_n(500))
non_pulsar_sample <- untidy(filter(htru_train, class == "Pulsar") |> sample_n(500))
histo_data <- bind_rows(pulsar_sample, non_pulsar_sample)
facet_labels <- c("p.mean" = "Mean (Integrated Profile)", 
                  "p.sd" = "Standard Deviation (Integrated Profile)", 
                  "p.kurt" = "Excessive Kurtosis (Integrated Profile)", 
                  "p.skew" = "Skewness (Integrated Profile)",
                  "c.mean" = "Mean (DM-SNR Curve)", 
                  "c.sd" = "Standard Deviation (DM-SNR Curve)", 
                  "c.kurt" = "Excessive Kurtosis (DM-SNR Curve)", 
                  "c.skew" = "Skewness (DM-SNR Curve)")

ggplot(histo_data, aes(x = vals, fill = as_factor(class), color = as_factor(class))) +
    geom_histogram(alpha = 0.5, position = "identity", bins = 30) +
    facet_wrap(vars(preds), nrow = 4, ncol = 2,
               scales = "free", 
               labeller = as_labeller(facet_labels)) +
    labs(x = "Value", y = "Count", fill = "Class", color = "Class",
         title = "\nDistributions of all numerical variables\n",
         caption = "Figure 1.1") +
    scale_color_brewer(palette = "Set2") +
    theme(text = element_text(size=20))
# Out:
# plot without title

# %% [markdown]
# The plots in Figure 1.0 show that most values do not have a significant overlap when segregating by the class of the pulsar candidate. This is best evidenced by the histogram describing the skewness of the integrated profile. The non-pulsar observations are extremely right-skewed, have almost no skewness and there is not much range in the data; whereas the pulsars have a relatively flat distribution and a large range of values. A similar visual analysis of the remaining histograms indicates that patterns can be identified in the data which will supports the notion further analysis of this data will be valuable to answer the research question and will provide meaningful insights into the domain of knowledge being explored. It can be said that there will not be a clear result that will not need its limitations to be discussed thoroughly. However, from just the preliminary data analysis, there is no hypothesis that can be made with a great deal of confidence.

# %% [markdown]
# To conduct the data analysis required to answer the devised question, all of the variables are used. Importantly, the class variable indicates whether the candidate is a pulsar or not; the remaining variables describe important and unique properties of the candidates. The data analysis is be conducted using classification, which allows prediction of the class for a pulsar candidate. The methodology for this data analysis is to test and train models of the data for each of the numerical variables, to determine which variable is most accurate in predicting the class of pulsar candidates. Specifically, k-nearest neighbors (KNN) classification is used, where the euclidean distance between neighbours is calculated to determine the class of the observations that are most similar to the candiate being determined.

# %% [markdown]
# It should be noted that two key steps in the K-NN classification are being omitted for this data analysis. The first being predictor variables selection, as this research question does not require the comination of predictors that yield the highest prediction accuracy to be found; as the goal of this data analysis is to find the one variable that is most accurate, which will still require forward selection. Additionally, the data will not be standardized as only one variable is being used at a time which ensures the measurement of distance will not be influenced by a different scales.

# %% [markdown]
# ### Data Analysis

# %% [markdown]
# The first step of the K-nn classification is to create 8 recipes for each of the 8 variables:

# %%
pm_recipe <- recipe(class ~ p.mean, data = htru_train)
cm_recipe <- recipe(class ~ c.mean, data = htru_train)
pd_recipe <- recipe(class ~ p.sd, data = htru_train)
cd_recipe <- recipe(class ~ c.sd, data = htru_train)
pk_recipe <- recipe(class ~ p.kurt, data = htru_train)
ck_recipe <- recipe(class ~ c.kurt, data = htru_train)
ps_recipe <- recipe(class ~ p.skew, data = htru_train)
cs_recipe <- recipe(class ~ c.skew, data = htru_train)

# %% [markdown]
# Then, a model for determining the number of neighbors for maximum accuracy and a vfold for the entire HTRU training data set is created:

# %%
set.seed(69420)

knn_tune <- nearest_neighbor(weight_func = "rectangular", neighbors = tune()) |>
       set_engine("kknn") |>
       set_mode("classification")

htru_vfold <- vfold_cv(htru_train, v = 5, strata = class)

# %% [markdown]
# Then, the accuracy for each combination of number of neighbors and variable is calculated and combined into a table, then it is plotted for easier visualization:
# (Warning: The code cell below should take 3-4 minutes to execute)

# %%
options(repr.plot.width=20, repr.plot.height=16)

knn_accuracies <- function(recipe) {
  workflow() |>
    add_recipe(recipe) |>
    add_model(knn_tune) |>
    tune_grid(resamples = htru_vfold, grid = 10) |>
    collect_metrics() |>
    filter(.metric == "accuracy") |>
    select(neighbors, mean)
}

recipes <- list(pm_recipe, cm_recipe, pd_recipe, cd_recipe,
                pk_recipe, ck_recipe, ps_recipe, cs_recipe)


results <- lapply(recipes, knn_accuracies)
  
factor_levels <- c("p.mean", "c.mean", "p.sd", "c.sd", "p.kurt", "c.kurt", "p.skew", "c.skew")

named_results <- bind_rows(mutate(results[[1]], variable = "p.mean"),
                           mutate(results[[2]], variable = "c.mean"),
                           mutate(results[[3]], variable = "p.sd"),
                           mutate(results[[4]], variable = "c.sd"),
                           mutate(results[[5]], variable = "p.kurt"),
                           mutate(results[[6]], variable = "c.kurt"),
                           mutate(results[[7]], variable = "p.skew"),
                           mutate(results[[8]], variable = "c.skew")) |> 
                 mutate(preds = factor(variable, levels = factor_levels))


cross_val_plot <- ggplot(named_results, aes(x = neighbors, y = mean, color = as_factor(variable))) +
       geom_point() +
       geom_line() +
       labs(x = "Neighbors", y = "Accuracy Estimate", color = "Variable",
         title = "\nAccuracy of each Predictor Variable for training\n",
         caption = "Figure 1.2") +
        scale_color_brewer(palette = "Set2") +
    theme(text = element_text(size=20))

cross_val_plot
# Out:
# plot without title

# %% [markdown]
# This is *not* the result of our data analysis, as this is only based on training data. However, it does allow a good K-value to be picked. By visual inspection of Figure 1.2, the ideal values for K would be:
# | Variable                                 | No. of neighbors |
# |:-----------------------------------------|-----------------:|
# | Mean of Integrated Profile               |                9 |
# | Mean of DM-SNR Curve                     |               13 |
# | Standard Deviation of Integrated Profile |               13 |
# | Standard Deviation of DM-SNR Curve       |               13 |
# | Excessive Kurtosis of Integrated Profile |                9 |
# | Excessive Kurtosis of DM-SNR Curve       |                7 |
# | Skewness of Integrated Profile           |                7 |
# | Skewness of DM-SNR Curve                 |               11 |
#
# <center>
# Table 1.0: Ideal K-values for classification
# </center>
# It should be noted that some lower numbers have been chosen as K-values have been chosen deliberately to avoid overfitting. Overfitting would entail a very high accuracy with the training data and high variance in the results because the model would be too influenced by the training data.

# %% [markdown]
# The k-values, that can be seen in Table 1.0, are then used to develop different models:

# %%
knn_spec_7 <- nearest_neighbor(weight_func = "rectangular", neighbors = 7) |>
              set_engine("kknn") |>
              set_mode("classification")
knn_spec_9 <- nearest_neighbor(weight_func = "rectangular", neighbors = 9) |>
              set_engine("kknn") |>
              set_mode("classification")
knn_spec_11 <- nearest_neighbor(weight_func = "rectangular", neighbors = 11) |>
               set_engine("kknn") |>
               set_mode("classification")
knn_spec_13 <- nearest_neighbor(weight_func = "rectangular", neighbors = 13) |>
               set_engine("kknn") |>
               set_mode("classification")

# %% [markdown]
# Then, different workflows are created for each of the different predictor variables:

# %%
htru_fit <- function(recipe, model) {
    workflow() |>
    add_recipe(recipe) |>
    add_model(model) |>
    fit(data = htru_train)
}

pm_fit <- htru_fit(pm_recipe, knn_spec_9)
cm_fit <- htru_fit(cm_recipe, knn_spec_13)
pd_fit <- htru_fit(pd_recipe, knn_spec_13)
cd_fit <- htru_fit(cd_recipe, knn_spec_13)
pk_fit <- htru_fit(pk_recipe, knn_spec_9)
ck_fit <- htru_fit(ck_recipe, knn_spec_7)
ps_fit <- htru_fit(ps_recipe, knn_spec_7)
cs_fit <- htru_fit(cs_recipe, knn_spec_11)

# %% [markdown]
# Finally, these different workflows are used to predict the testing set and their accuracy are measured and plotted on a bar chart:

# %%
options(repr.plot.width=20, repr.plot.height=16)

fits <- list(pm_fit, cm_fit, pd_fit, cd_fit,
             pk_fit, ck_fit, ps_fit, cs_fit)

measure_accuracy <- function(fit) {
    predict(fit, htru_test) |>
    bind_cols(select(htru_test, class)) |>
    metrics(truth = class, estimate = .pred_class) |>
    filter(.metric == "accuracy") |>
    select(.estimate) |>
    rename(accuracy = .estimate)
}

accuracies <- lapply(fits, measure_accuracy)

factor_levels <- c("p.mean", "c.mean", "p.sd", "c.sd", "p.kurt", "c.kurt", "p.skew", "c.skew")

named_accuracies <- bind_rows(mutate(accuracies[[1]], variable = "p.mean"),
                              mutate(accuracies[[2]], variable = "c.mean"),
                              mutate(accuracies[[3]], variable = "p.sd"),
                              mutate(accuracies[[4]], variable = "c.sd"),
                              mutate(accuracies[[5]], variable = "p.kurt"),
                              mutate(accuracies[[6]], variable = "c.kurt"),
                              mutate(accuracies[[7]], variable = "p.skew"),
                              mutate(accuracies[[8]], variable = "c.skew")) |> 
                    mutate(variable = factor(variable, levels = factor_levels))

accuracies_plot <- ggplot(named_accuracies, aes(x = variable, y = accuracy)) +
                   geom_col(aes(fill = variable)) +
                   labs(x = "Predictor", y = "Accuracy",
                         title = "\nAccuracy of each Predictor Variable with Testing Set\n",
                         caption = "Figure 1.3") +
                   scale_color_brewer(palette = "Set2") +
                   theme(text = element_text(size=20))
accuracies_plot
# Out:
# plot without title

# %%
print(named_accuracies)
# Out:
# # A tibble: 8 × 2
#   accuracy variable
#      <dbl> <fct>
# 1    0.965 p.mean
# 2    0.908 c.mean
# 3    0.929 p.sd
# 4    0.917 c.sd
# 5    0.979 p.kurt
# 6    0.909 c.kurt
# 7    0.968 p.skew
# 8    0.911 c.skew

# %% [markdown]
# <center>
# Table 1.1: Accuracy of each Predictor Variable

# %% [markdown]
# ## Discussion

# %% [markdown]
# #### Summary of results

# %% [markdown]
# From our data analysis, we can conclude, the excess kurtosis of the integrated profile is the characteristic of a pulsar candidate which best indicates whether it is a pulsar star or not, which has an accuracy of approximately 97.9%. This is closely followed by the mean of the integrated profile, 96.5%, and skewness of the integrated profile, 96.8%, as the most accurate predictors for a pulsar candidate.
#
# To fully answer the research question, we must define the excess kurtosis of the integrated profile. The integrated pulse profile of a pulsar is a graph/profile of data that outlines the emission of radiation with each pulse. Emission of a pulsar is one of its defining characteristics and therefore tracking it helps us collect vital data (West Virgina University). A kurtosis graph shows what general results should be, so when it is in excess, it becomes fatter or more positive, which indicates large amounts of emissions (Turney). In the case of a pulsar, the more emission and data we have the more we will be able to classify the pulsar candidate as an official pulsar. Essentially, if the integrated profile of a pulsar candidate has a somewhat uniform curve, it is likely that the candidate is a pulsar star.
#
# Exploring the next two most accurate characteristics, we can define the mean of the integrated profile as the average/ mean of pulses and their emission. Since this is an averaged amount considering all pulses from one pulsar, it is also going to be accurate when it comes to classification of pulsar candidates. The skewness of the integrated profile could help us determine if there are any rapid changes in the pulsar's emission pattern. Pulsars have very distinct patterns that define them individually, but as a whole they all follow the generally same shape. If we can match the skewing to the general patterns it would also benefit in helping us classify a pulsar candidate.
#
# To answer the research question, the excess kurtosis of the integrated profile of a pulsar candidate best indicates whether it is a pulsar star or not.

# %% [markdown]
# #### Evaluation of results

# %% [markdown]
# The preliminary data analysis indicated that the numerical variables all have notable differences in the patterns concerning their distributions; which made this data set conducive to a sound conclusion to be had from the data analysis. It was expected that there would be a result found from the data analysis that would have implications and limitations which must be discussed. In other words, we expected to find a trend, but were not certain what it would be, and did not offer a hypothesis due to a lack of confidence.
#
# It was not at all expected that all of the predictor variables would be elements of the integrated profile of the pulsar stars. In fact, even the fourth most accurate predictor is the Standard deviation of the integrated profile. The Integrated profile can be thought of as “raw data” in a sense that it collects the emission of pulses directly and lays it into a graph on a computer. Contrarily, the DM-SNR curve is created after formatting the data, and therefore we can understand that the integrated profile is going to be the most accurate when classifying pulsar candidates (West Virgina University).
#
# Focusing more on the top characteristic, excess kurtosis on integrated profile, it makes sense that this would be the most accurate because it measures the amount of radiation directly. If there is a pulsar candidate that is emitting a lot of pulsar radiation, how could you deny that the candidate is in fact a pulsar.

# %% [markdown]
# #### Possible impacts of results

# %% [markdown]
# The comprehension and understanding of pulsars is an area of astronomy and science that is still undergoing research. Using our findings, astronomers can consider the excess kurtosis data of the integrated profile to be more accurate than the other examples of data. Our findings could help shorten the process of pulsar classification, as scientists can focus on the most accurate data.
#
# At present, a pulsar candidate is discovered through sightings and radio signals. The data collected is then analyzed to determine characteristics of a pulsar. Machine learning and artificial intelligence is actively being incorporated to make the process of determining pulsar stars easier (Eatough).
#
# Our findings can improve the general approach being used right now and make the classification of pulsar candidates more efficient; which may have outreaching effects on academia and industries involved in astrophysics.
#
# It should be noted that the problem with using one predictor variable in a model is that there may be a great deal of variability in prediction when applied to various different data sets. However, the reverberating impacts of the result of our data analysis may inspire changes in the way the integrated profile of a pulsar candidate is determined leading to more effective and efficient prediction of pulsar stars.
#
# Nonetheless, the results of our analysis could indicate that a paradigm shift is well overdue in the domain of astrophysics; as dated methodologies and ideas continue to be applied despite continued advancement in technologies and our understanding of the universe.

# %% [markdown]
# #### Future questions incited by the results

# %% [markdown]
# Following are some possible research questions and studies that could result from our analysis:
# - How can groups of knowers and thinkers coalesce the established ideas and nuances in important industries and established domains of knowledge with progressive and radical ideas that are brought on by the equitable distribution of knowledge and technology in society?
# - Specifically, how can we combine the results of our analysis with the current methodologies being applied in academia and industry to develop a more efficient and reliable way of discerning pulsar candidates?
# - How can pre-existing models and processes be improved to better align with the rapid and relentless shift in technology trends given the rapid growth of technologies and rising number of changes in how the world is viewed?
# - Specifically, are there new data or data collection processes that can be applied, in tandem with the results of our analysis, to improve the way we are able to classify pulsar candidates?

# %% [markdown]
# ## Works Cited

# %% [markdown]
# Cofield, Calla. “What Are Pulsars?” Space.com, Space, 22 Apr. 2016, https://www.space.com/32661-pulsars.html#:~:text=Because%20pulsars%20are%20small%20and,the%20majority%20of%20known%20pulsars.
#
# Eatough, R. P., et al. "Selection of radio pulsar candidates using artificial neural networks." Monthly Notices of the Royal Astronomical Society 407.4 (2010): 2443-2450.
#
# Lorimer, D. R., and M. Kramer. Handbook of Pulsar Astronomy. Cambridge University Press, 2005.
#
# Lyon, R J. “Why Are Pulsars Hard To Find?” PhD Thesis, University of Manchester, 2016.
#
# Lyon, Robert J., et al. "Fifty years of pulsar candidate selection: from simple filters to a new principled real-time classification approach." Monthly Notices of the Royal Astronomical Society 459.1 (2016): 1104-1123.
#
# Turney, Shaun. “What Is Kurtosis?: Definition, Examples &amp; Formula.” Scribbr, 10 Nov. 2022, https://www.scribbr.com/statistics/kurtosis/.
#
# West Virginia University. 2017, http://ipta.phys.wvu.edu/files/student-week-2017/IPTA2017_KuoLiu_pulsartiming.pdf.

# %% [markdown]
# ...
